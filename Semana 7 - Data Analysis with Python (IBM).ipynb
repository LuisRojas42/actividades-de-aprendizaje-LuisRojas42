# %% [markdown]
# <h1><b>Semana 7: Data Analysis with Python (IBM)</b></h2>
#
# Luis Eduardo Rojas Zepeda - A01794121
#
# <b>Data Analysis with Python</b>
#
# <hr>
#
# <br>
#
# <h2>Module 4 - Model Development   </h2>
#
# <br>
#
# <b>Objetivos</b>
#
# *   Regresión lineal y lineal múltiple
# * Evaluación de modelos mediante visualización
# * Regresión polinomial y canalizaciones
# * Medidas para la evaluación dentro de la muestra
# * Predicción y toma de decisiones
#
#
# <br>
# <h5><b>Regresión lineal y lineal múltiple</b></h5>
# <br>
# La regresión lineal se referirá a una variable independiente para hacer una predicción.
# La regresión lineal múltiple se referirá a múltiples variables independientes para hacer una predicción.
# <br><br>
# 1. El predictor (variable independiente) - <i>x</i>
# <br>
# 2. El objetivo (variable dependiente) - <i>y</i>
# <br>
# 3. El interceptor - <i>bo</i>
# <br>
# 4. La pendiente - <i>b1</i>
# <br>
# <center>
# y = bo + b1x
# <br> y = bo + b1x1 + b2x2 + ... + bnxn
# </center>
#
#
# <br>
# <h5><b>Evaluación de modelos mediante visualización</b></h5>
# <br>
# Da un estimado de:
# <br>
# 1. La relación entre las variables
# <br>
# 2. La fuerza de la coorrelación
# <br>
# 3. La dirección de la coorrelación
# <br>
#
# <br>
# <h5><b>Regresión polinomial y canalizaciones</b></h5>
# <br>
# 1. La regresión polinomial es un caso especial de la regresión lineal general.
# <br>
# 2. Este método es beneficioso para describir relaciones curvilíneas.
# <br><br>
# El modelo puede ser cuadrático:
# <br><center> y = bo + b1x1 + b2(x1)^2</center>
# El modelo puede ser cúbico:
# <br><center> y = bo + b1x1 + b2(x1)^2 + b3(x1)^3</center>
# El modelo puede ser de orden mayor:
# <br><center> y = bo + b1x1 + b2(x1)^2 + b3(x1)^3 + ... +bn(x1)^n</center>

# %%
f = np.polyfit(x,y,3)
p = np.polyId(f)

# %% [markdown]
# <br>
# <h5><b>Medidas para la evaluación dentro de la muestra</b></h5>
# <br>
#
# Sirven para evaluar numéricamente nuestros modelos. Son una forma de determinar numéricamente qué tan bien se ajusta el modelo a nuestros datos.<br>
# Dos medidas importantes que usamos a menudo para determinar el ajuste de un modelo son:
# * Error (MSE)
# * R-squared.
#
# <br>
# <h5><b>Predicción y toma de decisiones</b></h5>
# <br>
# ¿Cómo podemos
# determinar si nuestro modelo es correcto?
# Primero se debe asegurar que los resultados del modelo tengan sentido.
# Siempre se debe usar Visualización, Medidas numéricas para evaluación y Comparación entre diferentes modelos

# %% [markdown]
# <h3><b>Lab 4 - Model Development</b></h3>

# %%
import piplite
await piplite.install(['pandas'])
await piplite.install(['matplotlib'])
await piplite.install(['scipy'])
await piplite.install(['seaborn'])
await piplite.install(['scikit-learn'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

# %%
await download(path, "auto.csv")
path="auto.csv"

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# <h2>1. Regresión lineal y regresión lineal múltiple</h2>

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lm.intercept_
# Out:
# 38423.30585815743

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# <h3>Cuestionario #1 a)</h3><br> Crear un objeto de regresion lineal llamado ml1

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# <h3>Cuestionario #1 b) </h3><br> Entrenar el modelo usando 'engine-size' como variable independiente y 'price' como variable dependiente.

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression()

# %% [markdown]
# <h3>Cuestionario #1 c) </h3><br> Encuentra el slope y el interpect del modelo.

# %%
lm1.coef_
# Out:
# array([[166.86001569]])

# %%
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# <h3>Cuestionario #1 d) </h3><br> ¿Cuál es la ecuacion del modelo?

# %%
Yhat=-7963.34 + 166.86*X

Price=-7963.34 + 166.86*df['engine-size']

# %% [markdown]
# <h4> Regresión de múltiples variables </h4>

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -15806.62462632922

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# Ecuación:<br>
#
# Price = -15678.742628061467 + 52.65851272 x horsepower + 4.69878948 x curb-weight + 81.95906216 x engine-size + 33.58258185 x highway-mpg

# %% [markdown]
# <h3> Cuestionario #2 a) </h3><br> Crea un modelo de regresión lineal múltiple con la variables 'normalized-losses' , 'highway-mpg' y 'price'.

# %%
lm2 = LinearRegression()
lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# <h3>Cuestionario #2 b) </h3><br> Encuentra el slope.

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# <h2> 2. Evaluación de modelos mediante visualización </h2>

# %%
import seaborn as sns
# %matplotlib inline

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48177.3640678429)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# <h3>Cuestionario #3</h3><br>Dadas las gráficas de regresión anteriores, ¿las "rpm pico" o "mpg en carretera" están más fuertemente correlacionadas con el "precio"? Usa el método ".corr()" para verificar tu respuesta.

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# <ipython-input-34-7377bca648c1>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# <ipython-input-34-7377bca648c1>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# <h2> 3. Regresión polinomial y canalizaciones </h2>

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# <h3>Cuestionario #4</h3><br> Cree un modelo polinomial de 11 órdenes con las variables x e y de arriba.

# %%
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
Z_pr.shape
# Out:
# (201, 15)

# %% [markdown]
# <h2>Pipeline</h2>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %% [markdown]
# <h3>Cuestionario #5</h3><br>Cree un pipeline que estandarice los datos, luego produzca una predicción usando un modelo de regresión lineal usando las características Z y el objetivo y.

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# <h2>4. Medidas para la evaluación dentro de la muestra</h2>

# %% [markdown]
# <h4>Model 1: Simple Linear Regression</h4>

# %%
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339176

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639888

# %% [markdown]
# <h4>Model 2: Multiple Linear Regression</h4>

# %%
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.87072649

# %% [markdown]
# <h4>Model 3: Polynomial Fit</h4>

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# <h2>5. Predicción y Toma de Decisiones</h2>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# /lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# <h2>Evidencia del Graded Review Questions</h2>

# %% [markdown]
# ![Screen Shot 2022-11-01 at 23.34.47.png](data:image/png;base64,...)
